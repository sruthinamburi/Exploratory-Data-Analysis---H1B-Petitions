# %%
library(ggplot2)
library(maps)

# %%
usa <- map_data("usa")
states <- map_data("state")

# %%
#print(states)

# %%
require(maps)
namevec <- map(database = "state", col = "white",fill=T, namesonly=T)
# Out:
# plot without title

# %%
c=c("washington","NEW HAMPSHIRE","ARKANSAS","DELAWARE","WISCONSIN")

# %%
map(database = "state",col = c("white", "blue")[1+(namevec %in% tolower(c) )],fill=T)
# Out:
# plot without title

# %%
#map(database = "state",col = c("red", "white")[1+(namevec %in% tolower("washington") )],fill=T)
